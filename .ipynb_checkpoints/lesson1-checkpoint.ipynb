# %%
import math
import numpy
from matplotlib import pyplot

# %% [markdown]
# ##hello

# %%
N = 50
x_start, x_end = -2.0, 2.0
y_start, y_end = -1.0, 1.0
x = numpy.linspace(x_start, x_end, N)
y = numpy.linspace(y_start, y_end, N)

print('x =', x)
print('y =', y)

X, Y = numpy.meshgrid(x, y)
# Out:
# x = [-2.         -1.91836735 -1.83673469 -1.75510204 -1.67346939 -1.59183673
#  -1.51020408 -1.42857143 -1.34693878 -1.26530612 -1.18367347 -1.10204082
#  -1.02040816 -0.93877551 -0.85714286 -0.7755102  -0.69387755 -0.6122449
#  -0.53061224 -0.44897959 -0.36734694 -0.28571429 -0.20408163 -0.12244898
#  -0.04081633  0.04081633  0.12244898  0.20408163  0.28571429  0.36734694
#   0.44897959  0.53061224  0.6122449   0.69387755  0.7755102   0.85714286
#   0.93877551  1.02040816  1.10204082  1.18367347  1.26530612  1.34693878
#   1.42857143  1.51020408  1.59183673  1.67346939  1.75510204  1.83673469
#   1.91836735  2.        ]
# y = [-1.         -0.95918367 -0.91836735 -0.87755102 -0.83673469 -0.79591837
#  -0.75510204 -0.71428571 -0.67346939 -0.63265306 -0.59183673 -0.55102041
#  -0.51020408 -0.46938776 -0.42857143 -0.3877551  -0.34693878 -0.30612245
#  -0.26530612 -0.2244898  -0.18367347 -0.14285714 -0.10204082 -0.06122449
# ...

# %%
# %matplotlib inline

size = 10
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
pyplot.xlabel('x', fontsize=10)
pyplot.ylabel('y', fontsize=10)
pyplot.xlim(x_start, x_end)
pyplot.ylim(y_start, y_end)
pyplot.scatter(X, Y, s=10, color='green', marker='o', linewidth=0)

# %%
strength_source = 5.0
x_source, y_source = -1.0, 0.25

u_source = strength_source/(2*math.pi) * (X-x_source)/((X-x_source)**2 + (Y-y_source)**2)
v_source = strength_source/(2*math.pi) * (Y-y_source)/((X-x_source)**2 + (Y-y_source)**2)

# %%
size = 15
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
pyplot.xlabel('x', fontsize=10)
pyplot.ylabel('y', fontsize=10)
pyplot.xlim(x_start, x_end)
pyplot.ylim(y_start, y_end)
pyplot.streamplot(X, Y, u_source, v_source, density=3, linewidth=1, arrowsize=2, arrowstyle='->')
pyplot.scatter(x_source, y_source, color='green', s=80, marker='o', linewidth=0);

# %%
strength_sink = -5.0
x_sink, y_sink = 1.0, 0.0

u_sink = strength_sink/(2*math.pi) * (X-x_sink)/((X-x_sink)**2 + (Y-y_sink)**2)
v_sink = strength_sink/(2*math.pi) * (Y-y_sink)/((X-x_sink)**2 + (Y-y_sink)**2)

# %%
size = 10
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
pyplot.xlabel('x', fontsize=10)
pyplot.ylabel('y', fontsize=10)
pyplot.xlim(x_start, x_end)
pyplot.ylim(y_start, y_end)
pyplot.streamplot(X, Y, u_sink, v_sink, density=2, linewidth=1, arrowsize=2, arrowstyle='->')
pyplot.scatter(x_sink, y_sink, color='green', s=80, marker='o', linewidth=0);

# %%
u_pair = u_source + u_sink
v_pair = v_source + v_sink

size = 15
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
pyplot.xlabel('x', fontsize=16)
pyplot.ylabel('y', fontsize=16)
pyplot.xlim(x_start, x_end)
pyplot.ylim(y_start, y_end)
pyplot.streamplot(X, Y, u_pair, v_pair, density=3.0, linewidth=1, arrowsize=2, arrowstyle='->')
pyplot.scatter([x_source, x_sink], [y_source, y_sink], 
            color='green', s=80, marker='o', linewidth=0);
